# %%
import pandas as pd
import numpy as np
import os
import csv
from scipy.stats import linregress

# %%
df = pd.read_csv(os.path.join('Data','csv','output','final_data.csv'))
df
# Out:
#       Year      Country  Primary Energy Consumption  \
# 0     1990       Canada                       10.83
# 1     1990       Mexico                        4.75
# 2     1990           US                       81.38
# 3     1990    Argentina                        1.85
# 4     1990       Brazil                        5.64
# ...    ...          ...                         ...
# 1499  2021    Indonesia                        7.76
# 1500  2021        Japan                       17.94
# 1501  2021  New Zealand                        0.85
# 1502  2021    Singapore                        3.28
# 1503  2021     Thailand                        5.01
#
#       Energy Consumption per Capita  CO2 Emissions  Energy Source Nuclear  \
# 0                             391.6          444.8                      0
# 1                              58.1          280.8                      0
# 2                             328.0         4970.5                      0
# 3                              56.6          100.3                      0
# 4                              37.4          206.4                      0
# ...                             ...            ...                    ...
# 1499                           28.3          519.6                      0
# 1500                          144.0         1066.6                      0
# 1501                          165.3           32.5                      0
# 1502                          551.9          213.3                      0
# 1503                           69.9          270.3                      0
#
#       Energy Source Coal, peat and oil shale  Energy Source Oil products  \
# 0                                        134                        2740
# 1                                         46                        2141
# 2                                       2329                       28608
# 3                                         18                         620
# 4                                        154                        2238
# ...                                      ...                         ...
# 1499                                     881                        2647
# 1500                                     843                        5510
# 1501                                      22                         270
# 1502                                       8                         519
# 1503                                     338                        2235
#
#       Energy Source Electricity  Energy Source Natural gas
# 0                          1505                       1813
# 1                           361                        582
# 2                          9481                      12689
# 3                           146                        421
# 4                           759                        106
# ...                         ...                        ...
# 1499                       1030                        689
# 1500                       3355                       1182
# 1501                        140                         94
# 1502                        193                         65
# 1503                        686                        225
#
# [1504 rows x 10 columns]

# %%
source_list = ['Energy Source Nuclear', 'Energy Source Coal, peat and oil shale', 'Energy Source Oil products', 'Energy Source Electricity', 'Energy Source Natural gas']
growth_df = pd.DataFrame(columns=['Year', 'Country', 'Energy Consumption per Capita'] + source_list)
rvalue_df = pd.DataFrame(columns=['Country', 'Source', 'R-Value', 'Strength', 'Direction'])

# %%
def calculate_growth(value, prev_value):
  if prev_value == 0:
    return np.nan
  else:
    growth = (value - prev_value) / prev_value * 100
    return growth

# %%
year_df_array = []

# For each unique year skipping the first year
for year in df['Year'].unique()[1:]:
  contry_df_array = []

  # For each unique country
  for country in df['Country'].unique():
    country_df = pd.DataFrame({ 'Country': country }, index=[0])

    # For each data column
    for column in ['Energy Consumption per Capita'] + source_list:
      # Get the value of the column for the given year and country
      value = df[(df['Year'] == year) & (df['Country'] == country)][column].values[0]

      # Get the value of the column for the previous year and country
      prev_value = df[(df['Year'] == year - 1) & (df['Country'] == country)][column].values[0]

      # Calculate the growth percentage
      growth = calculate_growth(value, prev_value)

      # Add the growth percentage to the country dataframe
      country_df[column] = growth

    contry_df_array.append(country_df)

  # Merge the country dataframes
  year_df = pd.concat(contry_df_array, ignore_index=True)

  # Add the year column
  year_df['Year'] = year

  # Reorder the columns
  year_df = year_df.reindex(columns=growth_df.columns)

  year_df_array.append(year_df)

# Merge the year dataframes
growth_df = pd.concat(year_df_array, ignore_index=True)
growth_df
# Out:
#       Year      Country  Energy Consumption per Capita  Energy Source Nuclear  \
# 0     1991       Canada                      -0.868233                    NaN
# 1     1991       Mexico                       0.860585                    NaN
# 2     1991           US                      -1.493902                    NaN
# 3     1991    Argentina                       0.176678                    NaN
# 4     1991       Brazil                       1.604278                    NaN
# ...    ...          ...                            ...                    ...
# 1452  2021    Indonesia                       1.071429                    NaN
# 1453  2021        Japan                       5.186267                    NaN
# 1454  2021  New Zealand                      -3.106682                    NaN
# 1455  2021    Singapore                      -0.612282                    NaN
# 1456  2021     Thailand                       0.575540                    NaN
#
#       Energy Source Coal, peat and oil shale  Energy Source Oil products  \
# 0                                   8.208955                   -4.014599
# 1                                 -19.565217                    5.137786
# 2                                  -1.373980                   -2.079838
# 3                                  -5.555556                    7.741935
# 4                                  18.181818                    1.385165
# ...                                      ...                         ...
# 1452                                3.891509                    2.557148
# 1453                                7.115629                   -0.738606
# 1454                                0.000000                    5.058366
# 1455                                0.000000                    4.637097
# 1456                               -5.056180                   -0.534045
#
#       Energy Source Electricity  Energy Source Natural gas
# 0                      0.930233                   1.930502
# 1                     -0.831025                   6.185567
# 2                      5.294800                  -0.859012
# 3                      4.109589                   1.187648
# 4                      3.162055                   4.716981
# ...                         ...                        ...
# 1452                   3.830645                  -1.991465
# 1453                   2.006689                   4.787234
# 1454                   0.000000                 -13.761468
# 1455                   5.464481                   4.838710
# 1456                   1.780415                   1.351351
#
# [1457 rows x 8 columns]

# %%
# Get "Positive" or "Negative" based on the rvalue
def get_direction(value):
  if value > 0:
    return 'Positive'
  elif value < 0:
    return 'Negative'
  else:
    return np.nan

# %%
# Get "Weak", "Moderate" or "Strong" based on the rvalue
def get_strength(value):
  if abs(value) < 0.3:
    return 'Weak'
  elif abs(value) < 0.7:
    return 'Moderate'
  else:
    return 'Strong'

# %%
contry_df_array = []

# For each unique country in growth_df
for country in growth_df['Country'].unique():
  # Get the country data
  country_data_df = growth_df[growth_df['Country'] == country]

  source_df_array = []

  # For each column in source_list
  for column in source_list:
    # Get the rvalue per source
    rvalue = linregress(country_data_df['Energy Consumption per Capita'], country_data_df[column]).rvalue

    source_df = pd.DataFrame({ 'Country': country, 'Source': column, 'R-Value': rvalue, 'Direction': get_direction(rvalue), 'Strength': get_strength(rvalue) }, index=[0])
    source_df_array.append(source_df)

  country_df = pd.concat(source_df_array, ignore_index=True)

  contry_df_array.append(country_df)

rvalue_df = pd.concat(contry_df_array, ignore_index=True)
rvalue_df
# Out:
#       Country                                  Source   R-Value Direction  \
# 0      Canada                   Energy Source Nuclear       NaN       NaN
# 1      Canada  Energy Source Coal, peat and oil shale  0.478987  Positive
# 2      Canada              Energy Source Oil products  0.717849  Positive
# 3      Canada               Energy Source Electricity  0.374916  Positive
# 4      Canada               Energy Source Natural gas  0.669038  Positive
# ..        ...                                     ...       ...       ...
# 230  Thailand                   Energy Source Nuclear       NaN       NaN
# 231  Thailand  Energy Source Coal, peat and oil shale  0.500284  Positive
# 232  Thailand              Energy Source Oil products  0.855777  Positive
# 233  Thailand               Energy Source Electricity  0.845621  Positive
# 234  Thailand               Energy Source Natural gas  0.581680  Positive
#
#      Strength
# 0      Strong
# 1    Moderate
# 2      Strong
# 3    Moderate
# 4    Moderate
# ..        ...
# 230    Strong
# 231  Moderate
# 232    Strong
# 233    Strong
# 234  Moderate
#
# [235 rows x 5 columns]
